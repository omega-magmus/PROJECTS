# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import seaborn as sns
sns.set()

# %%
raw_data=pd.read_csv("1.04.+Real-life+example (1).csv")

# %%
raw_data.describe(include="all")
# Out:
#              Brand          Price   Body      Mileage      EngineV  \
# count         4345    4173.000000   4345  4345.000000  4195.000000
# unique           7            NaN      6          NaN          NaN
# top     Volkswagen            NaN  sedan          NaN          NaN
# freq           936            NaN   1649          NaN          NaN
# mean           NaN   19418.746935    NaN   161.237284     2.790734
# std            NaN   25584.242620    NaN   105.705797     5.066437
# min            NaN     600.000000    NaN     0.000000     0.600000
# 25%            NaN    6999.000000    NaN    86.000000     1.800000
# 50%            NaN   11500.000000    NaN   155.000000     2.200000
# 75%            NaN   21700.000000    NaN   230.000000     3.000000
# max            NaN  300000.000000    NaN   980.000000    99.990000
#
#        Engine Type Registration         Year    Model
# count         4345         4345  4345.000000     4345
# unique           4            2          NaN      312
# top         Diesel          yes          NaN  E-Class
# freq          2019         3947          NaN      199
# mean           NaN          NaN  2006.550058      NaN
# std            NaN          NaN     6.719097      NaN
# min            NaN          NaN  1969.000000      NaN
# 25%            NaN          NaN  2003.000000      NaN
# 50%            NaN          NaN  2008.000000      NaN
# 75%            NaN          NaN  2012.000000      NaN
# max            NaN          NaN  2016.000000      NaN

# %%
data = raw_data.drop(['Model'],axis=1)

# %%
data.isnull().sum()
# Out:
# Brand             0
# Price           172
# Body              0
# Mileage           0
# EngineV         150
# Engine Type       0
# Registration      0
# Year              0
# dtype: int64

# %%
data_no_mv=data.dropna(axis=0)

# %%
sns.distplot(data_no_mv['Price'])
# Out:
# C:\Users\brijesh\AppData\Local\Temp\ipykernel_11052\216991009.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_no_mv['Price'])
# <Axes: xlabel='Price', ylabel='Density'>

# %%
sns.displot(data_1['Price'])
# Out:
# C:\Users\brijesh\anaconda3\lib\site-packages\seaborn\axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
q=data_no_mv['Price'].quantile(0.99)
data_1=data_no_mv[data_no_mv['Price']<q]
data_1
# Out:
#               Brand     Price       Body  Mileage  EngineV Engine Type  \
# 0               BMW    4200.0      sedan      277      2.0      Petrol
# 1     Mercedes-Benz    7900.0        van      427      2.9      Diesel
# 2     Mercedes-Benz   13300.0      sedan      358      5.0         Gas
# 3              Audi   23000.0  crossover      240      4.2      Petrol
# 4            Toyota   18300.0  crossover      120      2.0      Petrol
# ...             ...       ...        ...      ...      ...         ...
# 4339         Toyota   17900.0      sedan       35      1.6      Petrol
# 4340  Mercedes-Benz  125000.0      sedan        9      3.0      Diesel
# 4341            BMW    6500.0      sedan        1      3.5      Petrol
# 4342            BMW    8000.0      sedan      194      2.0      Petrol
# 4344     Volkswagen   13500.0        van      124      2.0      Diesel
#
#      Registration  Year
# 0             yes  1991
# 1             yes  1999
# 2             yes  2003
# 3             yes  2007
# 4             yes  2011
# ...           ...   ...
# 4339          yes  2014
# 4340          yes  2014
# 4341          yes  1999
# 4342          yes  1985
# 4344          yes  2013
#
# [3984 rows x 8 columns]

# %%
sns.distplot(data_no_mv['Mileage'])
# Out:
# C:\Users\brijesh\AppData\Local\Temp\ipykernel_17684\534165355.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_no_mv['Mileage'])
# <Axes: xlabel='Mileage', ylabel='Density'>

# %%
q=data_1['Mileage'].quantile(0.99)
data_2=data_1[data_1['Mileage']<q]
data_2
# Out:
#               Brand     Price       Body  Mileage  EngineV Engine Type  \
# 0               BMW    4200.0      sedan      277      2.0      Petrol
# 1     Mercedes-Benz    7900.0        van      427      2.9      Diesel
# 2     Mercedes-Benz   13300.0      sedan      358      5.0         Gas
# 3              Audi   23000.0  crossover      240      4.2      Petrol
# 4            Toyota   18300.0  crossover      120      2.0      Petrol
# ...             ...       ...        ...      ...      ...         ...
# 4339         Toyota   17900.0      sedan       35      1.6      Petrol
# 4340  Mercedes-Benz  125000.0      sedan        9      3.0      Diesel
# 4341            BMW    6500.0      sedan        1      3.5      Petrol
# 4342            BMW    8000.0      sedan      194      2.0      Petrol
# 4344     Volkswagen   13500.0        van      124      2.0      Diesel
#
#      Registration  Year
# 0             yes  1991
# 1             yes  1999
# 2             yes  2003
# 3             yes  2007
# 4             yes  2011
# ...           ...   ...
# 4339          yes  2014
# 4340          yes  2014
# 4341          yes  1999
# 4342          yes  1985
# 4344          yes  2013
#
# [3944 rows x 8 columns]

# %%
sns.distplot(data_2['Mileage'])
# Out:
# C:\Users\brijesh\AppData\Local\Temp\ipykernel_17684\1950307955.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_2['Mileage'])
# <Axes: xlabel='Mileage', ylabel='Density'>

# %%
data_3=data_2[data_2['EngineV']<6.5]

# %%
sns.distplot(data_2['Mileage'])
# Out:
# C:\Users\brijesh\AppData\Local\Temp\ipykernel_17684\1950307955.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_2['Mileage'])
# <Axes: xlabel='Mileage', ylabel='Density'>

# %%
sns.distplot(data_3['Year'])
# Out:
# C:\Users\brijesh\AppData\Local\Temp\ipykernel_17684\2525852583.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_3['Year'])
# <Axes: xlabel='Year', ylabel='Density'>

# %%
q=data_3['Year'].quantile(0.01)
data_4=data_3[data_3['Year']>q]

# %%
sns.distplot(data_4['Year'])
# Out:
# C:\Users\brijesh\AppData\Local\Temp\ipykernel_17684\2748958191.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_4['Year'])
# <Axes: xlabel='Year', ylabel='Density'>

# %%
data_cleaned=data_4.reset_index(drop=True)

# %%
f,(ax1,ax2,ax3)=plt.subplots(1,3,sharey=True,figsize=(25,3))
ax1.scatter(data_cleaned['Year'],data_cleaned['Price'])
ax1.set_title("price & year")
ax2.scatter(data_cleaned['EngineV'],data_cleaned['Price'])#ols assumption
ax2.set_title("price & enginev")
ax3.scatter(data_cleaned['Mileage'],data_cleaned['Price'])
ax3.set_title("price & Mileage")
plt.show()

# %%
log_price = np.log(data_cleaned['Price'])

# Then we add it to our data frame
data_cleaned['log_price'] = log_price
data_cleaned
# Out:
#               Brand     Price       Body  Mileage  EngineV Engine Type  \
# 0               BMW    4200.0      sedan      277      2.0      Petrol
# 1     Mercedes-Benz    7900.0        van      427      2.9      Diesel
# 2     Mercedes-Benz   13300.0      sedan      358      5.0         Gas
# 3              Audi   23000.0  crossover      240      4.2      Petrol
# 4            Toyota   18300.0  crossover      120      2.0      Petrol
# ...             ...       ...        ...      ...      ...         ...
# 3862     Volkswagen   11500.0        van      163      2.5      Diesel
# 3863         Toyota   17900.0      sedan       35      1.6      Petrol
# 3864  Mercedes-Benz  125000.0      sedan        9      3.0      Diesel
# 3865            BMW    6500.0      sedan        1      3.5      Petrol
# 3866     Volkswagen   13500.0        van      124      2.0      Diesel
#
#      Registration  Year  log_price
# 0             yes  1991   8.342840
# 1             yes  1999   8.974618
# 2             yes  2003   9.495519
# 3             yes  2007  10.043249
# 4             yes  2011   9.814656
# ...           ...   ...        ...
# 3862          yes  2008   9.350102
# 3863          yes  2014   9.792556
# 3864          yes  2014  11.736069
# 3865          yes  1999   8.779557
# 3866          yes  2013   9.510445
#
# [3867 rows x 9 columns]

# %%
f,(ax1,ax2,ax3)=plt.subplots(1,3,sharey=True,figsize=(25,3))
ax1.scatter(data_cleaned['Year'],data_cleaned['log_price'])
ax1.set_title("log_price & year")
ax2.scatter(data_cleaned['EngineV'],data_cleaned['log_price'])#ols assumption
ax2.set_title("log_price & enginev")
ax3.scatter(data_cleaned['Mileage'],data_cleaned['log_price'])
ax3.set_title("log_price & Mileage")
plt.show()

# %%
data_cleaned.columns.values
# Out:
# array(['Brand', 'Price', 'Body', 'Mileage', 'EngineV', 'Engine Type',
#        'Registration', 'Year', 'log_price'], dtype=object)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
variables=data_cleaned[['Mileage','Year','EngineV']]
vif=pd.DataFrame()
vif['VIF']=[variance_inflation_factor(variables.values,i) for i in range(variables.shape[1])]
vif
# Out:
#          VIF
# 0   3.791584
# 1  10.354854
# 2   7.662068

# %%
data_no_multicollinearty=data_cleaned.drop(['Year'],axis=1)

# %%
data_with_dummies=pd.get_dummies(data_no_multicollinearty,drop_first=True)

# %%
data_with_dummies.columns.values
# Out:
# array(['Price', 'Mileage', 'EngineV', 'log_price', 'Brand_BMW',
#        'Brand_Mercedes-Benz', 'Brand_Mitsubishi', 'Brand_Renault',
#        'Brand_Toyota', 'Brand_Volkswagen', 'Body_hatch', 'Body_other',
#        'Body_sedan', 'Body_vagon', 'Body_van', 'Engine Type_Gas',
#        'Engine Type_Other', 'Engine Type_Petrol', 'Registration_yes'],
#       dtype=object)

# %%
cols=['Price', 'Mileage', 'EngineV', 'log_price', 'Brand_BMW',
       'Brand_Mercedes-Benz', 'Brand_Mitsubishi', 'Brand_Renault',
       'Brand_Toyota', 'Brand_Volkswagen', 'Body_hatch', 'Body_other',
       'Body_sedan', 'Body_vagon', 'Body_van', 'Engine Type_Gas',
       'Engine Type_Other', 'Engine Type_Petrol', 'Registration_yes']

# %%
data_preprocessed=data_with_dummies[cols]

# %%
target=data_preprocessed['log_price']
input=data_preprocessed.drop(['log_price'],axis=1)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaler.fit(input)
# Out:
# StandardScaler()

# %%
input_scaled=scaler.transform(input)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(input_scaled,target,test_size=0.2,random_state=69)

# %%
reg=LinearRegression()
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_hat=reg.predict(x_train)

# %%
plt.scatter(y_train,y_hat)
plt.xlabel("target(y_train)",size=18)
plt.ylabel('Predictions (y_hat)',size=18)
plt.xlim(6,13)
plt.ylim(6,13)
plt.show()

# %%
sns.distplot(y_train - y_hat)

# Include a title
plt.title("Residuals PDF", size=18)
# Out:
# C:\Users\brijesh\AppData\Local\Temp\ipykernel_17684\4118303277.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y_train - y_hat)
# Text(0.5, 1.0, 'Residuals PDF')

# %%
reg.score(x_train,y_train)
# Out:
# 0.8655497227768442

# %%
reg.intercept_
# Out:
# 9.413591780732942

# %%
reg.coef_
# Out:
# array([-2.30923341e-01,  3.73526453e-02,  1.90486527e+12,  2.13960129e+12,
#        -3.68718530e+12, -2.28162258e+12,  3.12609729e+12,  1.60253843e+12,
#        -1.97473686e-02,  2.79235840e-03, -1.22070312e-03,  6.10351562e-05,
#         1.07421875e-02, -6.54296875e-02, -1.00708008e-02, -7.63397217e-02,
#         2.86376953e-01,  4.89044189e-02,  5.00488281e-02, -1.35192871e-02,
#         2.72064209e-02,  1.42950981e+12,  3.85742188e-02,  6.12182617e-02,
#         1.28265381e-01,  8.78906250e-03,  3.55834961e-02,  6.74438477e-02,
#         4.10156250e-02,  3.51257324e-02,  2.27355957e-02,  4.46472168e-02,
#         1.78146362e-01,  5.26123047e-02,  8.67309570e-02,  5.02624512e-02,
#         1.36108398e-01,  9.21173096e-02,  2.69470215e-02,  2.74658203e-02,
#         3.19824219e-02,  2.64892578e-02,  1.06445312e-01,  2.36206055e-02,
#         3.93981934e-02,  3.35083008e-02,  7.37609863e-02,  3.74298096e-02,
#         2.28424072e-02,  3.27148438e-02,  5.40771484e-02,  3.60107422e-02,
#         1.87664271e+11,  3.24703275e+11,  6.63806951e+11,  2.16658187e+11,
#         4.04621609e+11,  1.08527251e+12,  4.58475929e+11,  1.08385855e+11,
#         4.18749723e+11,  8.44109068e+11,  6.61557778e+10, -2.94370557e+11,
#        -7.90333995e+10, -2.99528275e+11, -7.90333995e+10,  3.06777954e-02,
#         8.77075195e-02,  5.52978516e-02,  5.40253990e+10,  8.53769055e+10,
#         1.76879883e-01,  6.38427734e-02,  6.83593750e-02,  4.26025391e-02,
#         4.14733887e-02,  6.35986328e-02,  4.03442383e-02,  3.08837891e-02,
#        -1.06139439e+12,  3.93218994e-02,  3.28979492e-02,  3.16162109e-02,
#         3.56445312e-02,  4.88586426e-02, -3.63442123e+11,  6.87255859e-02,
#         4.07714844e-02,  3.87850377e+11, -5.99445974e+11,  3.26220491e+11,
#         8.53769055e+10,  6.89453109e+11, -7.90333995e+10,  5.64635753e+11,
#         9.74352334e+11, -3.42326610e+11, -5.58948083e+10,  3.82083947e+10,
#         3.26220491e+11,  6.51757201e+11,  3.27636719e-01, -2.38494225e+12,
# %%
reg_summary=pd.DataFrame(input.columns.values,columns=['Features'])
reg_summary['weights']=reg.coef_
reg_summary
# Out:
#                Features   weights
# 0                 Price  0.454575
# 1               Mileage -0.216116
# 2               EngineV  0.105614
# 3             Brand_BMW  0.000759
# 4   Brand_Mercedes-Benz -0.016828
# 5      Brand_Mitsubishi -0.064182
# 6         Brand_Renault -0.103437
# 7          Brand_Toyota -0.014651
# 8      Brand_Volkswagen -0.037352
# 9            Body_hatch -0.086803
# 10           Body_other -0.036280
# 11           Body_sedan -0.095661
# 12           Body_vagon -0.062956
# 13             Body_van -0.076165
# 14      Engine Type_Gas -0.057237
# 15    Engine Type_Other -0.008283
# 16   Engine Type_Petrol -0.065682
# 17     Registration_yes  0.254984

# %%
#testing
data_cleaned["Brand"].unique()
# Out:
# array(['BMW', 'Mercedes-Benz', 'Audi', 'Toyota', 'Renault', 'Volkswagen',
#        'Mitsubishi'], dtype=object)

# %%
y_hat_test=reg.predict(x_test)

# %%
plt.scatter(y_test, y_hat_test, alpha=0.2)
plt.xlabel('Targets (y_test)',size=18)
plt.ylabel('Predictions (y_hat_test)',size=18)
plt.xlim(6,13)
plt.ylim(6,13)
plt.show()

# %%
df_pf=pd.DataFrame(np.exp(y_hat_test),columns=['prediction'])
df_pf.head()
# Out:
#      prediction
# 0  13209.764950
# 1  23016.671247
# 2  27596.778778
# 3   9199.520356
# 4   9271.583850

# %%
df_pf['target']=np.exp(y_test)

# %%
df_pf
# Out:
#        prediction   target
# 0    13209.764950      NaN
# 1    23016.671247   7900.0
# 2    27596.778778      NaN
# 3     9199.520356  23000.0
# 4     9271.583850      NaN
# ..            ...      ...
# 769  17833.960566   6950.0
# 770   2818.253974      NaN
# 771   9557.987904      NaN
# 772  18278.157023   7500.0
# 773  15543.520257      NaN
#
# [774 rows x 2 columns]

# %%
y_test=y_test.reset_index(drop=True)
y_test.head()
# Out:
# 0     9.740969
# 1    10.085809
# 2    10.707729
# 3     9.190138
# 4     9.137770
# Name: log_price, dtype: float64

# %%
df_pf['residual']=df_pf['target']-df_pf['prediction']

# %%
df_pf['diff%']=np.absolute(df_pf['residual']/df_pf['target']*100)

# %%
pd.options.display.max_rows = 999
# Moreover, to make the dataset clear, we can display the result with only 2 digits after the dot 
pd.set_option('display.float_format', lambda x: '%.2f' % x)
# Finally, we sort by difference in % and manually check the model
df_pf.sort_values(by=['diff%'])
# Out:
#      prediction    target   residual   diff%
# 670    15482.29  15500.00      17.71    0.11
# 504    13738.96  13500.00    -238.96    1.77
# 514    10546.25  10800.00     253.75    2.35
# 221     6922.68   7200.00     277.32    3.85
# 511     7798.27   7500.00    -298.27    3.98
# 380    10623.00  11300.00     677.00    5.99
# 417     6765.59   7200.00     434.41    6.03
# 306     8079.09   7600.00    -479.09    6.30
# 627    10221.47   9600.00    -621.47    6.47
# 368    13687.28  14800.00    1112.72    7.52
# 496    14508.87  15800.00    1291.13    8.17
# 638    54299.47  19000.00  -35299.47  185.79
# 662    24864.38   8700.00  -16164.38  185.80
# 1      23016.67   7900.00  -15116.67  191.35
# 376    13052.84   4300.00   -8752.84  203.55
# 609    23437.03   7700.00  -15737.03  204.38
# 573    28056.97   9000.00  -19056.97  211.74
# 650     9333.41   2900.00   -6433.41  221.84
# 98     16134.62   4900.00  -11234.62  229.28
# 235     9213.84   2600.00   -6613.84  254.38
# 546    11233.10   3100.00   -8133.10  262.36
# 318    21083.78   5800.00  -15283.78  263.51
# 607     9286.90   2500.00   -6786.90  271.48
# 458    40445.30  10800.00  -29645.30  274.49
# 242    31691.82   7700.00  -23991.82  311.58
# 343    40366.20   7800.00  -32566.20  417.52
# 731    18945.10   3650.00  -15295.10  419.04
# 274    22677.36   3600.00  -19077.36  529.93
# 89     30853.61   4500.00  -26353.61  585.64
# 503    64007.54   8500.00  -55507.54  653.03
# 16     27383.73   3500.00  -23883.73  682.39
# 294    15675.12   1950.00  -13725.12  703.85
# 521    59822.13   6500.00  -53322.13  820.34
# 602    80108.07   8000.00  -72108.07  901.35
# 382   270923.06  24999.00 -245924.06  983.74
# 273    89278.50   6200.00  -83078.50 1339.98
# 395    72790.16   4700.00  -68090.16 1448.73
# 474    75775.51   3400.00  -72375.51 2128.69
# 709    55542.67   1350.00  -54192.67 4014.27
# 0      13209.76       NaN        NaN     NaN
# 2      27596.78       NaN        NaN     NaN
# 4       9271.58       NaN        NaN     NaN
# 6       3334.33       NaN        NaN     NaN
# 7      22478.29       NaN        NaN     NaN
# 8      13689.48       NaN        NaN     NaN
# 9      11145.91       NaN        NaN     NaN
# 10     10272.44       NaN        NaN     NaN
# 11     12275.77       NaN        NaN     NaN
# 12      7241.14       NaN        NaN     NaN
# 13      9271.58       NaN        NaN     NaN
# 14      7503.09       NaN        NaN     NaN
# 15      8393.49       NaN        NaN     NaN
# 17      2594.70       NaN        NaN     NaN
# 18      7954.80       NaN        NaN     NaN
# 19     15511.68       NaN        NaN     NaN
# 20      6405.04       NaN        NaN     NaN
# 21     13163.32       NaN        NaN     NaN
# 22     11348.74       NaN        NaN     NaN
# 23     45267.35       NaN        NaN     NaN
# 24      7163.87       NaN        NaN     NaN
# 25     26107.12       NaN        NaN     NaN
# 27      6885.40       NaN        NaN     NaN
# 28     21162.74       NaN        NaN     NaN
# 29      9450.41       NaN        NaN     NaN
# 30      9314.34       NaN        NaN     NaN
# 32     17991.48       NaN        NaN     NaN
# 33     14785.94       NaN        NaN     NaN
# 34    228712.47       NaN        NaN     NaN
# 35     13165.85       NaN        NaN     NaN
# 36     17651.62       NaN        NaN     NaN
# 37     30258.36       NaN        NaN     NaN
# 38      4381.24       NaN        NaN     NaN
# 39      7760.98       NaN        NaN     NaN
# 40     10279.52       NaN        NaN     NaN
# 41     15165.23       NaN        NaN     NaN
# 42     18480.22       NaN        NaN     NaN
# 44     12411.50       NaN        NaN     NaN
# 45     11478.34       NaN        NaN     NaN
# 49      8556.31       NaN        NaN     NaN
# 50     51654.40       NaN        NaN     NaN
# 53    270814.53       NaN        NaN     NaN
# 54      6912.36       NaN        NaN     NaN
# 56     11295.44       NaN        NaN     NaN
# 57      9256.26       NaN        NaN     NaN
# 60     22113.00       NaN        NaN     NaN
# 61      8098.90       NaN        NaN     NaN
# 62      7159.66       NaN        NaN     NaN
# 63      7913.04       NaN        NaN     NaN
# 64     20221.63       NaN        NaN     NaN
# 65     18119.06       NaN        NaN     NaN
# 66     24615.69       NaN        NaN     NaN
# 67     13830.99       NaN        NaN     NaN
# 68     11325.57       NaN        NaN     NaN
# 70      9127.01       NaN        NaN     NaN
# 73      6257.26       NaN        NaN     NaN
# 74     14634.40       NaN        NaN     NaN
# 75    343655.24       NaN        NaN     NaN
# 77     10474.97       NaN        NaN     NaN
# 79     40718.00       NaN        NaN     NaN
# 80     13822.44       NaN        NaN     NaN
# 81     14170.77       NaN        NaN     NaN
# 82     14877.60       NaN        NaN     NaN
# 84     10051.07       NaN        NaN     NaN
# 85     16892.36       NaN        NaN     NaN
# 86      6902.96       NaN        NaN     NaN
# 87      7366.64       NaN        NaN     NaN
# 90      6762.12       NaN        NaN     NaN
# 91     11081.18       NaN        NaN     NaN
# 93     26386.49       NaN        NaN     NaN
# 96     14393.27       NaN        NaN     NaN
# 97     27753.66       NaN        NaN     NaN
# 101    11727.86       NaN        NaN     NaN
# 102    22026.46       NaN        NaN     NaN
# 103    11385.27       NaN        NaN     NaN
# 104    15034.24       NaN        NaN     NaN
# 105    10406.87       NaN        NaN     NaN
# 106     8930.51       NaN        NaN     NaN
# 107    22928.23       NaN        NaN     NaN
# 108     7456.75       NaN        NaN     NaN
# 109   245921.98       NaN        NaN     NaN
# 110    21866.34       NaN        NaN     NaN
# 111     7732.47       NaN        NaN     NaN
# 113    21366.68       NaN        NaN     NaN
# 114    49780.56       NaN        NaN     NaN
# 115     5683.45       NaN        NaN     NaN
# 116    40366.20       NaN        NaN     NaN
# 117     8582.08       NaN        NaN     NaN
# 118    12846.51       NaN        NaN     NaN
# 119    13986.48       NaN        NaN     NaN
# 120     5346.53       NaN        NaN     NaN
# 121     6762.41       NaN        NaN     NaN
# 122    14265.87       NaN        NaN     NaN
# 123     9752.68       NaN        NaN     NaN
# 124     3948.17       NaN        NaN     NaN
# 125    10546.31       NaN        NaN     NaN
# 126    26532.11       NaN        NaN     NaN
# 127    48010.39       NaN        NaN     NaN
# 128     9591.36       NaN        NaN     NaN
# 129     9783.29       NaN        NaN     NaN
# 130     7406.27       NaN        NaN     NaN
# 131    18224.67       NaN        NaN     NaN
# 132    10466.35       NaN        NaN     NaN
# 133    17695.00       NaN        NaN     NaN
# 134   155769.37       NaN        NaN     NaN
# 135     7642.81       NaN        NaN     NaN
# 136    15911.93       NaN        NaN     NaN
# 137     6461.82       NaN        NaN     NaN
# 138    17632.14       NaN        NaN     NaN
# 140    15442.39       NaN        NaN     NaN
# 225    13164.14       NaN        NaN     NaN
# 226    34873.18       NaN        NaN     NaN
# 227    11620.07       NaN        NaN     NaN
# 228     7503.99       NaN        NaN     NaN
# 229     3946.33       NaN        NaN     NaN
# 230     2523.11       NaN        NaN     NaN
# 231    18509.83       NaN        NaN     NaN
# 232    11576.64       NaN        NaN     NaN
# 233     7335.31       NaN        NaN     NaN
# 234    16859.87       NaN        NaN     NaN
# 236     3373.23       NaN        NaN     NaN
# 237     4686.20       NaN        NaN     NaN
# 238    22223.18       NaN        NaN     NaN
# 239     7057.60       NaN        NaN     NaN
# 240    38224.17       NaN        NaN     NaN
# 243     7622.05       NaN        NaN     NaN
# 245    45115.72       NaN        NaN     NaN
# 246     3380.99       NaN        NaN     NaN
# 247     8428.25       NaN        NaN     NaN
# 251    23371.85       NaN        NaN     NaN
# 253    17267.82       NaN        NaN     NaN
# 254     6610.69       NaN        NaN     NaN
# 255     6826.89       NaN        NaN     NaN
# 256     3385.70       NaN        NaN     NaN
# 257     8568.77       NaN        NaN     NaN
# 258    42219.04       NaN        NaN     NaN
# 259     9261.06       NaN        NaN     NaN
# 260    17514.34       NaN        NaN     NaN
# 261    17785.54       NaN        NaN     NaN
# 262   165225.20       NaN        NaN     NaN
# 264    11649.12       NaN        NaN     NaN
# 267    11381.21       NaN        NaN     NaN
# 268     3218.38       NaN        NaN     NaN
# 270     7807.74       NaN        NaN     NaN
# 272    48939.45       NaN        NaN     NaN
# 275     9077.30       NaN        NaN     NaN
# 276    15214.20       NaN        NaN     NaN
# 277    13405.63       NaN        NaN     NaN
# 278    24886.06       NaN        NaN     NaN
# 279     3463.13       NaN        NaN     NaN
# 281     8649.56       NaN        NaN     NaN
# 282    12954.18       NaN        NaN     NaN
# 283    21064.73       NaN        NaN     NaN
# 284    17320.99       NaN        NaN     NaN
# 285     7945.77       NaN        NaN     NaN
# 286    14397.02       NaN        NaN     NaN
# 287    10536.92       NaN        NaN     NaN
# 288    11297.40       NaN        NaN     NaN
# 289     7606.25       NaN        NaN     NaN
# 290     7834.62       NaN        NaN     NaN
# 291     4705.19       NaN        NaN     NaN
# 292     6487.89       NaN        NaN     NaN
# 295    12835.98       NaN        NaN     NaN
# 296     2450.34       NaN        NaN     NaN
# 297    39815.85       NaN        NaN     NaN
# 298    16391.47       NaN        NaN     NaN
# 299    14563.32       NaN        NaN     NaN
# 300     8754.66       NaN        NaN     NaN
# 301    10454.33       NaN        NaN     NaN
# 302    12130.21       NaN        NaN     NaN
# 303     8284.34       NaN        NaN     NaN
# 304     3131.66       NaN        NaN     NaN
# 305    20862.43       NaN        NaN     NaN
# 308     5889.11       NaN        NaN     NaN
# 310    10124.34       NaN        NaN     NaN
# 311    29757.41       NaN        NaN     NaN
# 312    86520.02       NaN        NaN     NaN
# 313     7725.40       NaN        NaN     NaN
# 314     9643.79       NaN        NaN     NaN
# 315     2977.98       NaN        NaN     NaN
# 316    66750.46       NaN        NaN     NaN
# 688    14302.34       NaN        NaN     NaN
# 689     7500.81       NaN        NaN     NaN
# 690    30343.12       NaN        NaN     NaN
# 691    14032.69       NaN        NaN     NaN
# 694    16417.99       NaN        NaN     NaN
# 696    10315.28       NaN        NaN     NaN
# 697    37763.36       NaN        NaN     NaN
# 698    11592.89       NaN        NaN     NaN
# 699    17127.87       NaN        NaN     NaN
# 700    19878.46       NaN        NaN     NaN
# 701    65393.06       NaN        NaN     NaN
# 703    17765.04       NaN        NaN     NaN
# 704    12337.41       NaN        NaN     NaN
# 705     3663.07       NaN        NaN     NaN
# 706     3102.29       NaN        NaN     NaN
# 707     3367.35       NaN        NaN     NaN
# 708    18427.11       NaN        NaN     NaN
# 710    62737.38       NaN        NaN     NaN
# 711    12070.21       NaN        NaN     NaN
# 712    15109.84       NaN        NaN     NaN
# 715    18740.16       NaN        NaN     NaN
# 716    17635.78       NaN        NaN     NaN
# 717    24984.96       NaN        NaN     NaN
# 719     5757.99       NaN        NaN     NaN
# 720    38984.81       NaN        NaN     NaN
# 721     7214.35       NaN        NaN     NaN
# 722     5941.11       NaN        NaN     NaN
# 724    10213.26       NaN        NaN     NaN
# 725    70185.60       NaN        NaN     NaN
# 727     9986.88       NaN        NaN     NaN
# 729     3138.69       NaN        NaN     NaN
# 730    12769.30       NaN        NaN     NaN
# 732    21366.32       NaN        NaN     NaN
# 733     7794.24       NaN        NaN     NaN
# 734    18355.50       NaN        NaN     NaN
# 735    38466.13       NaN        NaN     NaN
# 736     9936.77       NaN        NaN     NaN
# 737    15220.35       NaN        NaN     NaN
# 738     7210.70       NaN        NaN     NaN
# 739     8017.81       NaN        NaN     NaN
# 740     9502.95       NaN        NaN     NaN
# 741    10676.73       NaN        NaN     NaN
# 742     5573.71       NaN        NaN     NaN
# 743    31888.34       NaN        NaN     NaN
# 744    31100.03       NaN        NaN     NaN
# 745    18001.36       NaN        NaN     NaN
# 746     9131.95       NaN        NaN     NaN
# 747    22772.67       NaN        NaN     NaN
# 748    21903.60       NaN        NaN     NaN
# 749    16142.74       NaN        NaN     NaN
# 750    13047.69       NaN        NaN     NaN
# 751     9429.27       NaN        NaN     NaN
# 752    21079.43       NaN        NaN     NaN
# 753    20818.33       NaN        NaN     NaN
# 754    14121.84       NaN        NaN     NaN
# 755     7786.56       NaN        NaN     NaN
# 756     3558.13       NaN        NaN     NaN
# 758    26864.47       NaN        NaN     NaN
# 759    20551.47       NaN        NaN     NaN
# 760     9504.67       NaN        NaN     NaN
# 761    12703.23       NaN        NaN     NaN
# 762    16646.21       NaN        NaN     NaN
# 763     9412.72       NaN        NaN     NaN
# 764    31517.94       NaN        NaN     NaN
# 765     6688.92       NaN        NaN     NaN
# 766   132471.46       NaN        NaN     NaN
# 767    10669.81       NaN        NaN     NaN
# 768    81530.95       NaN        NaN     NaN
# 770     2818.25       NaN        NaN     NaN
# 771     9557.99       NaN        NaN     NaN
# 773    15543.52       NaN        NaN     NaN
